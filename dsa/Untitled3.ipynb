# %% [markdown]
# **Sorting algorithms**

# %% [markdown]
# Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        isSwap = False   # reset for each pass
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                isSwap = True
        if not isSwap:   # no swaps → already sorted
            break
    return arr

print(bubble_sort([1, 10, 9, 7, 12]))
# Out:
# [1, 7, 9, 10, 12]

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(nums):
    n = len(nums)
    for i in range(1, n):
        key = nums[i]
        j = i - 1
        while j >= 0 and nums[j] > key:
            nums[j + 1] = nums[j]
            j -= 1
        nums[j + 1] = key
    return nums

print(insertion_sort([1, 10, 9, 7, 12]))
# Out:
# [1, 7, 9, 10, 12]

# %% [markdown]
# Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    # remaining elements
    result.extend(left[i:])
    result.extend(right[j:])

    return result


arr = [8, 3, 5, 2, 7, 1]
print(merge_sort(arr))
# Out:
# [1, 2, 3, 5, 7, 8]
